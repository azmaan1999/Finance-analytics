# %%
import pandas_datareader as pdr
import datetime 

aapl = pdr.get_data_yahoo('AAPL', start = datetime.datetime(2006, 10,1), end = datetime.datetime(2020,4,23))

# %%
#returns first few rows of aaple stock 
aapl.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2006-10-02  10.838572  10.614285  10.728572  10.694285  178159800.0   9.258014
# 2006-10-03  10.707143  10.455714  10.635715  10.582857  197677200.0   9.161551
# 2006-10-04  10.780000  10.451428  10.585714  10.768572  207270700.0   9.322326
# 2006-10-05  10.880000  10.590000  10.647142  10.690000  170970800.0   9.254304
# 2006-10-06  10.720000  10.544286  10.631429  10.602858  116739700.0   9.178867

# %%
#returns last days of apple stock up to 4/23
aapl.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-04-17  286.950012  276.859985  284.690002  282.799988  53812500.0
# 2020-04-20  281.679993  276.850006  277.950012  276.929993  32503800.0
# 2020-04-21  277.250000  265.429993  276.279999  268.369995  45247900.0
# 2020-04-22  277.899994  272.200012  273.609985  276.100006  29264300.0
# 2020-04-23  281.750000  274.869995  275.869995  275.029999  31203600.0
#
#              Adj Close
# Date
# 2020-04-17  282.036530
# 2020-04-20  276.182373
# 2020-04-21  267.645477
# 2020-04-22  275.354614
# 2020-04-23  274.287506

# %%
#provides solid spread of each data element
aapl.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  3413.000000  3413.000000  3413.000000  3413.000000  3.413000e+03
# mean     93.440959    91.617153    92.528019    92.564497  1.091375e+08
# std      69.587706    68.244945    68.850924    68.966833  9.674611e+07
# min      10.568571    10.371428    10.488571    10.461429  1.136200e+07
# 25%      30.478571    29.860001    30.297142    30.138571  3.616230e+07
# 50%      79.761429    78.142860    79.150002    79.018570  7.988690e+07
# 75%     129.190002   127.110001   128.190002   128.449997  1.503957e+08
# max     327.850006   323.350006   324.739990   327.200012  8.432424e+08
#
#          Adj Close
# count  3413.000000
# mean     86.900407
# std      68.976226
# min       9.056430
# 25%      26.090879
# 50%      69.905052
# 75%     117.897400
# max     326.316681

# %%
#turns the apple stock dataset into a csv file for later use in case apple api doesnt work later on
#df variable which reads the csv file 

import pandas as pd 
aapl.to_csv('appleset.csv', encoding = 'utf-8')

#now takes in the csv file 
df = pd.read_csv('appleset.csv', header = 0 , index_col = 'Date', parse_dates = True)

# %%
#head or top 5 of the dataset
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2006-10-02  10.838572  10.614285  10.728572  10.694285  178159800.0   9.258014
# 2006-10-03  10.707143  10.455714  10.635715  10.582857  197677200.0   9.161551
# 2006-10-04  10.780000  10.451428  10.585714  10.768572  207270700.0   9.322326
# 2006-10-05  10.880000  10.590000  10.647142  10.690000  170970800.0   9.254304
# 2006-10-06  10.720000  10.544286  10.631429  10.602858  116739700.0   9.178867

# %%
#index of the dataset
df.index
# Out:
# DatetimeIndex(['2006-10-02', '2006-10-03', '2006-10-04', '2006-10-05',
#                '2006-10-06', '2006-10-09', '2006-10-10', '2006-10-11',
#                '2006-10-12', '2006-10-13',
#                ...
#                '2020-04-09', '2020-04-13', '2020-04-14', '2020-04-15',
#                '2020-04-16', '2020-04-17', '2020-04-20', '2020-04-21',
#                '2020-04-22', '2020-04-23'],
#               dtype='datetime64[ns]', name='Date', length=3413, freq=None)

# %%
#columns of dataset
df.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
#prints out last 10 price points at closing for apple stock
ts = df['Close'][-10:]
print(ts)
# Out:
# Date
# 2020-04-09    267.989990
# 2020-04-13    273.250000
# 2020-04-14    287.049988
# 2020-04-15    284.429993
# 2020-04-16    286.690002
# 2020-04-17    282.799988
# 2020-04-20    276.929993
# 2020-04-21    268.369995
# 2020-04-22    276.100006
# 2020-04-23    275.029999
# Name: Close, dtype: float64

# %%
# Inspect the first rows of November-December 2006
print(df.loc[pd.Timestamp('2006-11-01'):pd.Timestamp('2006-12-31')]. head())

# Inspect the first rows of 2007 
print(df.loc['2007'].head())

# Inspect November 2006
print(df.iloc[22:43])

# Inspect the 'Open' and 'Close' values at 2006-11-01 and 2006-12-01
print(df.iloc[[22,43], [0, 3]])
# Out:
# High        Low       Open      Close       Volume  Adj Close
# Date
# 2006-11-01  11.625714  11.194285  11.585714  11.308572  152798100.0   9.789802
# 2006-11-02  11.331429  11.214286  11.274285  11.282857  116370800.0   9.767539
# 2006-11-03  11.361428  11.112857  11.337143  11.184286  107972200.0   9.682207
# 2006-11-06  11.437143  11.204286  11.278571  11.387143  108644200.0   9.857821
# 2006-11-07  11.571428  11.447143  11.492857  11.501429  131483100.0   9.956757
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2007-01-03  12.368571  11.700000  12.327143  11.971429  309579900.0  10.363638
# 2007-01-04  12.278571  11.974286  12.007143  12.237143  211815100.0  10.593664
# 2007-01-05  12.314285  12.057143  12.252857  12.150000  208685400.0  10.518225
# 2007-01-08  12.361428  12.182858  12.280000  12.210000  199276700.0  10.570165
# 2007-01-09  13.282857  12.164286  12.350000  13.224286  837324600.0  11.448232
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2006-11-01  11.625714  11.194285  11.585714  11.308572  152798100.0   9.789802
# 2006-11-02  11.331429  11.214286  11.274285  11.282857  116370800.0   9.767539
# 2006-11-03  11.361428  11.112857  11.337143  11.184286  107972200.0   9.682207
# 2006-11-06  11.437143  11.204286  11.278571  11.387143  108644200.0   9.857821
# 2006-11-07  11.571428  11.447143  11.492857  11.501429  131483100.0   9.956757
# 2006-11-08  11.812857  11.412857  11.431429  11.778571  172729200.0  10.196676
# 2006-11-09  12.098572  11.731428  11.842857  11.905714  230763400.0  10.306746
# 2006-11-10  11.942857  11.785714  11.935715  11.874286   93466100.0  10.279537
# 2006-11-13  12.064285  11.805715  11.888572  12.050000  112668500.0  10.431654
# 2006-11-14  12.142858  11.985714  12.114285  12.142858  147238700.0  10.512039
# 2006-11-15  12.271428  12.000000  12.150000  12.007143  163830800.0  10.394552
# 2006-11-16  12.328571  12.088572  12.124286  12.230000  173485200.0  10.587480
# 2006-11-17  12.277143  12.142858  12.162857  12.264286  116606000.0  10.617161
# 2006-11-20  12.428572  12.171429  12.200000  12.352858  142698500.0  10.693839
# 2006-11-21  12.657143  12.444285  12.488571  12.657143  155666700.0  10.957254
# 2019-12-31  275.126224
# 2020-01-31  310.337596
# 2020-02-29  310.271843
# 2020-03-31  261.735581
# 2020-04-30  267.641749
#
# [163 rows x 6 columns]

# %%
df.head()
#creates a new column with difference between open and close prices
df['diff']= df.Open-df.Close

df.head()
# Out:
#                  High        Low       Open      Close       Volume  \
# Date
# 2006-10-02  10.838572  10.614285  10.728572  10.694285  178159800.0
# 2006-10-03  10.707143  10.455714  10.635715  10.582857  197677200.0
# 2006-10-04  10.780000  10.451428  10.585714  10.768572  207270700.0
# 2006-10-05  10.880000  10.590000  10.647142  10.690000  170970800.0
# 2006-10-06  10.720000  10.544286  10.631429  10.602858  116739700.0
#
#             Adj Close      diff
# Date
# 2006-10-02   9.258014  0.034286
# 2006-10-03   9.161551  0.052857
# 2006-10-04   9.322326 -0.182858
# 2006-10-05   9.254304 -0.042857
# 2006-10-06   9.178867  0.028571

# %%
#imports matplotlib to plot the graph
import matplotlib.pyplot as plt
#plots the closing timeline over the years
df['Close'].plot(grid = True)

# %%
#plots the fluctuation in differences
df['diff'].plot(grid = True)

# %%
import numpy as np 

#adj close to daily close assignment
daily_close = df['Adj Close']

#checking out last closed figures
daily_close.tail()
# Out:
# Date
# 2020-04-17    282.036530
# 2020-04-20    276.182373
# 2020-04-21    267.645477
# 2020-04-22    275.354614
# 2020-04-23    274.287506
# Name: Adj Close, dtype: float64

# %%
#calculates percent change 
daily_pct_change = daily_close.pct_change()

#replace na values with 0 
daily_pct_change.fillna(0,inplace = True)
print(daily_pct_change)
# Out:
# Date
# 2006-10-02    0.000000
# 2006-10-03   -0.010419
# 2006-10-04    0.017549
# 2006-10-05   -0.007297
# 2006-10-06   -0.008152
# 2006-10-09    0.005524
# 2006-10-10   -0.010988
# 2006-10-11   -0.007858
# 2006-10-12    0.027721
# 2006-10-13   -0.003189
# 2006-10-16    0.005065
# 2006-10-17   -0.014721
# 2006-10-18    0.003230
# 2006-10-19    0.059842
# 2006-10-20    0.012154
# 2006-10-23    0.018887
# 2006-10-24   -0.005033
# 2006-10-25    0.007773
# 2006-10-26    0.006244
# 2006-10-27   -0.021657
# 2006-10-30    0.000124
# 2006-10-31    0.008207
# 2006-11-01   -0.023680
# 2006-11-02   -0.002274
# 2006-11-03   -0.008736
# 2006-11-06    0.018138
# 2006-11-07    0.010036
# 2006-11-08    0.024096
# 2006-11-09    0.010795
# 2006-11-10   -0.002640
#                 ...
# 2020-03-12   -0.098755
# 2020-03-13    0.119808
# 2020-03-16   -0.128647
# 2020-03-17    0.043970
# 2020-03-18   -0.024480
# 2020-03-19   -0.007662
# 2020-03-20   -0.063486
# 2020-03-23   -0.021244
# 2020-03-24    0.100325
# 2020-03-25   -0.005509
# 2020-03-26    0.052623
# 2020-03-27   -0.041402
# 2020-03-30    0.028538
# 2020-03-31   -0.002041
# 2020-04-01   -0.052617
# 2020-04-02    0.016687
# 2020-04-03   -0.014371
# 2020-04-06    0.087237
# 2020-04-07   -0.011582
# 2020-04-08    0.025595
# 2020-04-09    0.007216
# 2020-04-13    0.019628
# 2020-04-14    0.050503
# 2020-04-15   -0.009127
# 2020-04-16    0.007946
# 2020-04-17   -0.013569
# 2020-04-20   -0.020757
# 2020-04-21   -0.030910
# 2020-04-22    0.028804
# 2020-04-23   -0.003875
# Name: Adj Close, Length: 3413, dtype: float64

# %%
#daily log returns
daily_log_returns = np.log(daily_close.pct_change()+1)
print(daily_log_returns)

daily_log_returns.plot(grid = True)
# Out:
# Date
# 2006-10-02         NaN
# 2006-10-03   -0.010474
# 2006-10-04    0.017397
# 2006-10-05   -0.007323
# 2006-10-06   -0.008185
# 2006-10-09    0.005509
# 2006-10-10   -0.011048
# 2006-10-11   -0.007889
# 2006-10-12    0.027344
# 2006-10-13   -0.003194
# 2006-10-16    0.005053
# 2006-10-17   -0.014831
# 2006-10-18    0.003225
# 2006-10-19    0.058120
# 2006-10-20    0.012080
# 2006-10-23    0.018711
# 2006-10-24   -0.005046
# 2006-10-25    0.007743
# 2006-10-26    0.006225
# 2006-10-27   -0.021895
# 2006-10-30    0.000124
# 2006-10-31    0.008173
# 2006-11-01   -0.023965
# 2006-11-02   -0.002277
# 2006-11-03   -0.008775
# 2006-11-06    0.017975
# 2006-11-07    0.009986
# 2006-11-08    0.023810
# 2006-11-09    0.010737
# 2006-11-10   -0.002643
#                 ...
# 2020-03-12   -0.103978
# 2020-03-13    0.113157
# 2020-03-16   -0.137708
# 2020-03-17    0.043031
# 2020-03-18   -0.024785
# 2020-03-19   -0.007692
# 2020-03-20   -0.065590
# 2020-03-23   -0.021473
# 2020-03-24    0.095606
# 2020-03-25   -0.005524
# 2020-03-26    0.051285
# 2020-03-27   -0.042284
# 2020-03-30    0.028138
# 2020-03-31   -0.002043
# 2020-04-01   -0.054052
# 2020-04-02    0.016549
# 2020-04-03   -0.014476
# 2020-04-06    0.083640
# 2020-04-07   -0.011650
# 2020-04-08    0.025273
# 2020-04-09    0.007190
# 2020-04-13    0.019438
# 2020-04-14    0.049269
# 2020-04-15   -0.009169
# 2020-04-16    0.007914
# 2020-04-17   -0.013662
# 2020-04-20   -0.020975
# 2020-04-21   -0.031398
# 2020-04-22    0.028397
# 2020-04-23   -0.003883
# Name: Adj Close, Length: 3413, dtype: float64

# %%
#calculates daily pct changes without builtin function
daily_pct_change = daily_close/daily_close.shift(1)-1

print(daily_pct_change)
# Out:
# Date
# 2006-10-02         NaN
# 2006-10-03   -0.010419
# 2006-10-04    0.017549
# 2006-10-05   -0.007297
# 2006-10-06   -0.008152
# 2006-10-09    0.005524
# 2006-10-10   -0.010988
# 2006-10-11   -0.007858
# 2006-10-12    0.027721
# 2006-10-13   -0.003189
# 2006-10-16    0.005065
# 2006-10-17   -0.014721
# 2006-10-18    0.003230
# 2006-10-19    0.059842
# 2006-10-20    0.012154
# 2006-10-23    0.018887
# 2006-10-24   -0.005033
# 2006-10-25    0.007773
# 2006-10-26    0.006244
# 2006-10-27   -0.021657
# 2006-10-30    0.000124
# 2006-10-31    0.008207
# 2006-11-01   -0.023680
# 2006-11-02   -0.002274
# 2006-11-03   -0.008736
# 2006-11-06    0.018138
# 2006-11-07    0.010036
# 2006-11-08    0.024096
# 2006-11-09    0.010795
# 2006-11-10   -0.002640
#                 ...
# 2020-03-12   -0.098755
# 2020-03-13    0.119808
# 2020-03-16   -0.128647
# 2020-03-17    0.043970
# 2020-03-18   -0.024480
# 2020-03-19   -0.007662
# 2020-03-20   -0.063486
# 2020-03-23   -0.021244
# 2020-03-24    0.100325
# 2020-03-25   -0.005509
# 2020-03-26    0.052623
# 2020-03-27   -0.041402
# 2020-03-30    0.028538
# 2020-03-31   -0.002041
# 2020-04-01   -0.052617
# 2020-04-02    0.016687
# 2020-04-03   -0.014371
# 2020-04-06    0.087237
# 2020-04-07   -0.011582
# 2020-04-08    0.025595
# 2020-04-09    0.007216
# 2020-04-13    0.019628
# 2020-04-14    0.050503
# 2020-04-15   -0.009127
# 2020-04-16    0.007946
# 2020-04-17   -0.013569
# 2020-04-20   -0.020757
# 2020-04-21   -0.030910
# 2020-04-22    0.028804
# 2020-04-23   -0.003875
# Name: Adj Close, Length: 3413, dtype: float64

# %%
#imports matplotlib
import matplotlib.pyplot as plt

daily_pct_change.hist(bins = 50)

daily_pct_change.describe()
# Out:
# count    3412.000000
# mean        0.001200
# std         0.020303
# min        -0.179196
# 25%        -0.007925
# 50%         0.001001
# 75%         0.011239
# max         0.139049
# Name: Adj Close, dtype: float64

# %%
cum_daily_return = (1+ daily_pct_change).cumprod()

print(cum_daily_return)
# Out:
# Date
# 2006-10-02          NaN
# 2006-10-03     0.989581
# 2006-10-04     1.006947
# 2006-10-05     0.999599
# 2006-10-06     0.991451
# 2006-10-09     0.996928
# 2006-10-10     0.985974
# 2006-10-11     0.978226
# 2006-10-12     1.005343
# 2006-10-13     1.002137
# 2006-10-16     1.007214
# 2006-10-17     0.992386
# 2006-10-18     0.995592
# 2006-10-19     1.055170
# 2006-10-20     1.067994
# 2006-10-23     1.088165
# 2006-10-24     1.082688
# 2006-10-25     1.091103
# 2006-10-26     1.097917
# 2006-10-27     1.074139
# 2006-10-30     1.074272
# 2006-10-31     1.083089
# 2006-11-01     1.057441
# 2006-11-02     1.055036
# 2006-11-03     1.045819
# 2006-11-06     1.064788
# 2006-11-07     1.075474
# 2006-11-08     1.101389
# 2006-11-09     1.113278
# 2006-11-10     1.110339
#                 ...
# 2020-03-12    26.740062
# 2020-03-13    29.943742
# 2020-03-16    26.091571
# 2020-03-17    27.238820
# 2020-03-18    26.572014
# 2020-03-19    26.368418
# 2020-03-20    24.694405
# 2020-03-23    24.169792
# 2020-03-24    26.594637
# 2020-03-25    26.448133
# 2020-03-26    27.839914
# 2020-03-27    26.687278
# 2020-03-30    27.448879
# 2020-03-31    27.392863
# 2020-04-01    25.951531
# 2020-04-02    26.384576
# 2020-04-03    26.005391
# 2020-04-06    28.274036
# 2020-04-07    27.946558
# 2020-04-08    28.661841
# 2020-04-09    28.868666
# 2020-04-13    29.435291
# 2020-04-14    30.921865
# 2020-04-15    30.639633
# 2020-04-16    30.883087
# 2020-04-17    30.464043
# 2020-04-20    29.831709
# 2020-04-21    28.909600
# 2020-04-22    29.742299
# 2020-04-23    29.627036
# Name: Adj Close, Length: 3413, dtype: float64

# %%
#pecent change in daily returns over time
cum_daily_return.plot()

# %%
#function which gets the data from more than one company

def get(tickers, startdate, enddate):
  def data(ticker):
    return (pdr.get_data_yahoo(ticker, start=startdate, end=enddate))
  datas = map (data, tickers)
  return(pd.concat(datas, keys=tickers, names=['Ticker', 'Date']))

tickers = ['AAPL', 'MSFT', 'IBM', 'GOOG']
all_data = get(tickers, datetime.datetime(2006, 10, 1), datetime.datetime(2012, 1, 1))

# %%
# Isolate the `Adj Close` values and transform the DataFrame
daily_close_px = all_data[['Adj Close']].reset_index().pivot('Date', 'Ticker', 'Adj Close')

# Calculate the daily percentage change for `daily_close_px`
daily_pct_change = daily_close_px.pct_change()

# Plot the distributions
daily_pct_change.hist(bins=50, sharex=True, figsize=(12,8))

# Show the resulting plot
plt.show()

# %%
from pandas.plotting import scatter_matrix

# Plot scatter matrix with the `daily_pct_change` data 
scatter_matrix(daily_pct_change, diagonal='kde', alpha=0.1,figsize=(12,12))

# Show the plot
plt.show()

# %%
# Import the `api` model of `statsmodels` under alias `sm`
import statsmodels.api as sm

# Import the `datetools` module from `pandas`
#from pandas.core import datetools

# Isolate the adjusted closing price
all_adj_close = all_data[['Adj Close']]

# Calculate the returns 
all_returns = np.log(all_adj_close / all_adj_close.shift(1))

# Isolate the AAPL returns 
aapl_returns = all_returns.iloc[all_returns.index.get_level_values('Ticker') == 'AAPL']
aapl_returns.index = aapl_returns.index.droplevel('Ticker')

# Isolate the MSFT returns
msft_returns = all_returns.iloc[all_returns.index.get_level_values('Ticker') == 'MSFT']
msft_returns.index = msft_returns.index.droplevel('Ticker')

# Build up a new DataFrame with AAPL and MSFT returns
return_data = pd.concat([aapl_returns, msft_returns], axis=1)[1:]
return_data.columns = ['AAPL', 'MSFT']

# Add a constant 
X = sm.add_constant(return_data['AAPL'])

# Construct the model
model = sm.OLS(return_data['MSFT'],X).fit()

# Print the summary
print(model.summary())
# Out:
# OLS Regression Results
# ==============================================================================
# Dep. Variable:                   MSFT   R-squared:                       0.281
# Model:                            OLS   Adj. R-squared:                  0.280
# Method:                 Least Squares   F-statistic:                     515.5
# Date:                Thu, 14 May 2020   Prob (F-statistic):           1.33e-96
# Time:                        04:16:41   Log-Likelihood:                 3514.0
# No. Observations:                1322   AIC:                            -7024.
# Df Residuals:                    1320   BIC:                            -7014.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.000     -1.119      0.263      -0.001       0.000
# AAPL           0.4407      0.019     22.704      0.000       0.403       0.479
# ==============================================================================
# Omnibus:                      268.593   Durbin-Watson:                   2.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7029.433
# Skew:                          -0.211   Prob(JB):                         0.00
# Kurtosis:                      14.289   Cond. No.                         41.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
